# %% [markdown]
# ### Import Libraries
#
# * we

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import string

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import feature_extraction
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
from wordcloud import WordCloud

# %%
fake=pd.read_csv('data/fake_new.csv')
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year‚...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama‚Äôs Na...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject       date
# 0  Donald Trump just couldn t wish all Americans ...    News  31-Dec-17
# 1  House Intelligence Committee Chairman Devin Nu...    News  31-Dec-17
# 2  On Friday, it was revealed that former Milwauk...    News  30-Dec-17
# 3  On Christmas day, Donald Trump announced that ...    News  29-Dec-17
# 4  Pope Francis used his annual Christmas Day mes...    News  25-Dec-17

# %%
real=pd.read_csv('data/True_new.csv')
real.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject       date
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews  31-Dec-17
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews  29-Dec-17
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews  31-Dec-17
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews  30-Dec-17
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews  29-Dec-17

# %%
plt.figure(figsize=(5,5)) 
plt.pie([real.shape[0], fake.shape[0]],labels=['real news', 'fake news'], shadow=False)#pie chart
# Out:
# ([<matplotlib.patches.Wedge at 0x7ff1c39be040>,
#   <matplotlib.patches.Wedge at 0x7ff1c39be4c0>],
#  [Text(6.735557395310444e-17, 1.1, 'real news'),
#   Text(-2.0206672185931328e-16, -1.1, 'fake news')])

# %%
fig,a =  plt.subplots(2,1, figsize=(8,8)) 
sns.countplot(x='subject', data=real, ax=a[0])
sns.countplot(x='subject', data=fake, ax=a[1])

# %%
real['textlength']=real['text'].str.len()
fake['textlength']=fake['text'].str.len()


fig,a =  plt.subplots(2,1, figsize=(8,8)) 
sns.distplot(real['textlength'], ax=a[0])
sns.distplot(fake['textlength'], ax=a[1])

# real['textlength']
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
# From wordcloud import WordCloud

alltextreal=' '.join(set([wd for wd in real['text']]))
alltextfake=' '.join(set([wd for wd in fake['text']]))


wc1 = WordCloud(background_color="white", max_words=200, width=1000, height=800).generate(alltextreal)
wc2 = WordCloud(background_color="white", max_words=200, width=1000, height=800).generate(alltextfake)


fig,a =  plt.subplots(2,1,figsize=(20,10))
a[0].imshow(wc1, interpolation='bilinear')
a[0].axis("off")
a[0].set_title('real news word cloud')

a[1].imshow(wc2, interpolation='bilinear')
a[1].axis("off")
a[1].set_title('fake news word cloud')
plt.show()

# %%
prcessed = WordCloud().process_text(alltextreal)

# %%
sortedfreqreal={k: v for k, v in sorted(prcessed.items(), key=lambda item: -item[1])}
sortedfreqreal
# Out:
# {'said': 74,
#  'Trump': 61,
#  'Äô': 61,
#  'Äù': 55,
#  'U S': 38,
#  'Republican': 34,
#  'will': 24,
#  'package': 19,
#  'state': 18,
#  'President': 17,
#  'law': 17,
#  'tax': 17,
#  'investigation': 17,
#  'Democrat': 16,
#  'Trump Äôs': 16,
#  'transgender': 15,
#  'federal': 15,
#  'administration': 15,
#  'year': 15,
#  'Amazon': 15,
#  'Mueller': 15,
#  'election': 14,
#  'Russia': 14,
#  'Postal Service': 14,
#  'Senate': 13,
#  'campaign': 13,
#  'Donald Trump': 13,
#  'New York': 13,
#  'New': 12,
#  'Department': 12,
#  'billion': 12,
#  'President Donald': 12,
#  'White House': 12,
#  'Reuters': 11,
#  'challenge': 11,
#  'government': 11,
#  'percent': 11,
#  'House': 11,
#  'program': 11,
#  'people': 10,
#  'Time': 10,
#  'military': 10,
#  'Jan': 10,
#  'Congress': 10,
#  'want': 10,
#  'bit ly': 10,
#  'Moore': 9,
#  'Court': 9,
#  'official': 9,
#  'Service': 9,
#  'Democratic': 9,
#  'Representative': 9,
#  'spending': 9,
#  'may': 9,
#  'Cuomo': 9,
#  'tax bill': 9,
#  'statement': 8,
#  'interview': 8,
#  'told': 8,
#  'early': 8,
#  'policy': 8,
#  'right': 8,
#  'Papadopoulos': 8,
#  'according': 8,
#  'comment': 8,
#  'WASHINGTON Reuters': 8,
#  'Thursday': 7,
#  'denied': 7,
#  'called': 7,
#  'reported': 7,
#  'WASHINGTON': 7,
#  'Friday': 7,
#  'set': 7,
#  'saying': 7,
#  'pay': 7,
#  'budget': 7,
#  'immigration': 7,
#  'issue': 7,
#  'former': 7,
#  'Strong': 7,
#  'United States': 7,
#  'Post Office': 7,
#  'Jones': 6,
#  'seat': 6,
#  'first': 6,
#  'Merrill': 6,
#  'work': 6,
#  'Dec': 6,
#  'Wednesday': 6,
#  'conservative': 6,
#  'way': 6,
#  'country': 6,
#  'Obama': 6,
#  'protection': 6,
#  'protect': 6,
#  'EST': 6,
#  'many': 6,
#  'day': 6,
#  'need': 6,
#  'DACA': 6,
#  'allies': 6,
#  'without': 6,
#  'Mnuchin': 6,
#  'tax overhaul': 6,
#  'York Times': 6,
#  'Special Counsel': 6,
#  'Alabama': 5,
#  'judge': 5,
#  'Secretary': 5,
#  'Governor': 5,
#  'declined': 5,
#  'even': 5,
#  'ÄúWe': 5,
#  'continue': 5,
#  'lawmakers': 5,
#  'appeal': 5,
#  'ban': 5,
#  'week': 5,
#  'begin': 5,
#  'defense': 5,
#  'expected': 5,
#  'applicants': 5,
#  'lawyer': 5,
#  'see': 5,
#  'American': 5,
#  'costs': 5,
#  'California': 5,
#  'legal': 5,
#  'use': 5,
#  'posted': 5,
#  'POTUS': 5,
#  'edited': 5,
#  'debt': 5,
#  'congressional': 5,
#  'Health': 5,
#  'Äôre': 5,
#  'bill': 5,
#  'passed': 5,
#  'border': 5,
#  'Florida': 5,
#  'FBI': 5,
#  'probe': 5,
#  'team': 5,
#  'Senator': 5,
#  'look': 5,
#  'long': 5,
#  'high': 5,
#  'cap': 5,
#  'property': 5,
#  'taxes': 5,
#  'revenue': 5,
#  'trade': 5,
#  'individual': 5,
#  'delivery': 5,
#  'business': 5,
#  'UPS': 5,
#  'last week': 5,
#  'took office': 5,
#  'majority': 4,
#  'victory': 4,
#  'decision': 4,
#  'Monday': 4,
#  'Pentagon': 4,
#  'rulings': 4,
#  'Two': 4,
#  'one': 4,
#  'last': 4,
#  'Justice': 4,
#  'ÄúThe': 4,
#  'plan': 4,
#  'meet': 4,
#  'ÄúI': 4,
#  'come': 4,
#  'filed': 4,
#  'four': 4,
#  'Constitution': 4,
#  'realDonaldTrump': 4,
#  'confirmed': 4,
#  'talk': 4,
#  'despite': 4,
#  'dollars': 4,
#  'charging': 4,
#  'making': 4,
#  'fighters': 4,
#  'voted': 4,
#  'month': 4,
#  'Sunday': 4,
#  'Meadows': 4,
#  'CBS': 4,
#  'January': 4,
#  'control': 4,
#  'big': 4,
#  'going': 4,
#  'raise': 4,
#  'party': 4,
#  'trillion': 4,
#  'think': 4,
#  'Ryan': 4,
#  'take': 4,
#  'funding': 4,
#  'wall': 4,
#  'Dreamers': 4,
#  'aid': 4,
#  'Australian': 4,
#  'political': 4,
#  'charge': 4,
#  'Graham': 4,
#  'question': 4,
#  'legislative': 4,
#  'leader': 4,
#  'Christmas': 4,
#  'known': 4,
#  'end': 4,
#  'past': 4,
#  'parcel': 4,
#  'tweet': 4,
#  'company': 4,
#  'price': 4,
#  'shipping': 4,
#  'FedEx': 4,
#  'mail': 4,
#  'cut': 4,
#  'Supreme Court': 4,
#  'equal protection': 4,
#  'following statements': 4,
#  'verified Twitter': 4,
#  'Twitter accounts': 4,
#  'opinions expressed': 4,
#  'accuracy realDonaldTrump': 4,
#  'EST Source': 4,
#  'Source link': 4,
#  'link bit': 4,
#  'ly 2jBh4LU': 4,
#  '2jBh4LU bit': 4,
#  'ly 2jpEXYR': 4,
#  'square miles': 4,
#  'West Palm': 4,
#  'Palm Beach': 4,
#  'don Äôt': 4,
#  'Los Angeles': 4,
#  'previously': 3,
#  'Jeff': 3,
#  'attorney': 3,
#  'results': 3,
#  'ÄúA': 3,
#  'request': 3,
#  'meeting': 3,
#  'possible': 3,
#  'Äôve': 3,
#  'CNN': 3,
#  'accused': 3,
#  'back': 3,
#  'put': 3,
#  'lower': 3,
#  'accepting': 3,
#  'recruits': 3,
#  'announced': 3,
#  'independent': 3,
#  'study': 3,
#  'speaking': 3,
#  'September': 3,
#  'serving': 3,
#  'members': 3,
#  'order': 3,
#  'must': 3,
#  'group': 3,
#  'good': 3,
#  'supporters': 3,
#  'medical': 3,
#  'Seattle': 3,
#  'issued': 3,
#  'likely': 3,
#  'personnel': 3,
#  'needed': 3,
#  'based': 3,
#  'public': 3,
#  'showed': 3,
#  'Post': 3,
#  'office': 3,
#  'others': 3,
#  'little': 3,
#  'deliver': 3,
#  'MUCH': 3,
#  'left': 3,
#  'associates': 3,
#  'November': 3,
#  'increase': 3,
#  'infrastructure': 3,
#  'fiscal': 3,
#  'run': 3,
#  'late': 3,
#  'December': 3,
#  'Crowley': 3,
#  'children': 3,
#  'March': 3,
#  'immigrants': 3,
#  'recent': 3,
#  'help': 3,
#  'fair': 3,
#  'hit': 3,
#  'took': 3,
#  'diplomat': 3,
#  'presidential': 3,
#  'Saturday': 3,
#  'intelligence': 3,
#  'information': 3,
#  'current': 3,
#  'foreign': 3,
#  'including': 3,
#  'April': 3,
#  'almost': 3,
#  'report': 3,
#  'collusion': 3,
#  'second': 3,
#  'dossier': 3,
#  'hurt': 3,
#  'David': 3,
#  'break': 3,
#  'agreement': 3,
#  'companies': 3,
#  'system': 3,
#  'wrote': 3,
#  'Treasury': 3,
#  'residents': 3,
#  'signed': 3,
#  'income': 3,
#  'Amendment': 3,
#  'professor': 3,
#  'rate': 3,
#  'call': 3,
#  'lost': 3,
#  'know': 3,
#  'base': 3,
#  'home': 3,
#  'agent': 3,
#  'Postal': 3,
#  'holiday': 3,
#  'total': 3,
#  'Jindel': 3,
#  'Attorney General': 3,
#  'hard line': 3,
#  'non defense': 3,
#  'Hillary Clinton': 3,
#  'first major': 3,
#  'Counsel Robert': 3,
#  'due process': 3,
#  'SALT deduction': 3,
#  'Secret Service': 3,
#  'certified': 2,
#  'Doug': 2,
#  'winner': 2,
#  'U': 2,
#  'race': 2,
#  'Roy': 2,
#  'whose': 2,
#  'sexual': 2,
#  'misconduct': 2,
#  'won': 2,
#  'votes': 2,
#  'made': 2,
#  'win': 2,
#  'tapped': 2,
#  'John': 2,
#  'Steve': 2,
#  'parties': 2,
#  'defeat': 2,
#  'urged': 2,
#  'certification': 2,
#  'media': 2,
#  'met': 2,
#  'scheduled': 2,
#  'show': 2,
#  'money': 2,
#  'yet': 2,
#  'claim': 2,
#  'several': 2,
#  'women': 2,
#  '30s': 2,
#  'allegations': 2,
#  'enlist': 2,
#  'decided': 2,
#  'releasing': 2,
#  'rather': 2,
#  'defend': 2,
#  'created': 2,
#  'panel': 2,
#  'prohibit': 2,
#  'hoping': 2,
#  'happen': 2,
#  'prepared': 2,
#  'standards': 2,
#  'Levi': 2,
#  'GLAD': 2,
#  'Äôm': 2,
#  'July': 2,
#  'reversing': 2,
#  'Barack': 2,
#  'Twitter': 2,
#  'violate': 2,
#  'process': 2,
#  'fit': 2,
#  'deadline': 2,
#  'James': 2,
#  'date': 2,
#  'taken': 2,
#  'gender': 2,
#  'another': 2,
#  'February': 2,
#  'allow': 2,
#  'low': 2,
#  'rating': 2,
#  'losing': 2,
#  'richer': 2,
#  'dumber': 2,
#  'poorer': 2,
#  'ÄúOn': 2,
#  'inaugurated': 2,
#  'territory': 2,
#  'Iraq': 2,
#  'Syria': 2,
#  'remaining': 2,
#  'jamiejmcintyre': 2,
#  'great': 2,
#  'national': 2,
#  'sharp': 2,
#  'among': 2,
#  'Mark': 2,
#  'Nation': 2,
#  'drew': 2,
#  'return': 2,
#  'pass': 2,
#  'fight': 2,
#  'keep': 2,
#  'research': 2,
#  'discretionary': 2,
#  'small': 2,
#  'give': 2,
#  'Äôt': 2,
#  'deficit': 2,
#  'Joseph': 2,
#  'future': 2,
#  'finance': 2,
#  'ÄúThis': 2,
#  'responsible': 2,
#  'biggest': 2,
#  'job': 2,
#  'recently': 2,
#  'Äúentitlement': 2,
#  'top': 2,
#  'mean': 2,
#  'poor': 2,
#  'well': 2,
#  'seeking': 2,
#  'social': 2,
#  'ÄúDreamers': 2,
#  'brought': 2,
#  'illegally': 2,
#  'young': 2,
#  'deportation': 2,
#  'permits': 2,
#  'Mexican': 2,
#  'changes': 2,
#  'followed': 2,
#  'weekend': 2,
#  'hurricanes': 2,
#  'Texas': 2,
#  'wildfires': 2,
#  'countries': 2,
#  'beside': 2,
#  'candidate': 2,
#  'Moscow': 2,
#  'contacts': 2,
#  'counterparts': 2,
#  'emails': 2,
#  'online': 2,
#  'newspaper': 2,
#  'cited': 2,
#  'Bureau': 2,
#  'British': 2,
#  'international': 2,
#  'claimed': 2,
#  'Russian': 2,
#  'criminal': 2,
#  'played': 2,
#  'aide': 2,
#  'role': 2,
#  'major': 2,
#  'now': 2,
#  'led': 2,
#  'hung': 2,
#  'ago': 2,
#  'biased': 2,
#  'immediately': 2,
#  'charged': 2,
#  'interfering': 2,
#  'interference': 2,
#  'shut': 2,
#  'committees': 2,
#  'undercut': 2,
#  'meddling': 2,
#  'prompted': 2,
#  'somebody': 2,
#  'used': 2,
#  'matter': 2,
#  'Fla': 2,
#  'kick': 2,
#  'wrapped': 2,
#  'flurry': 2,
#  'chief': 2,
#  'Short': 2,
#  'McConnell': 2,
#  'term': 2,
#  'ended': 2,
#  'provided': 2,
#  'number': 2,
#  'pushed': 2,
#  'security': 2,
#  'promised': 2,
#  'understand': 2,
#  'Lottery': 2,
#  'Flake': 2,
#  'fix': 2,
#  'ceiling': 2,
#  'code': 2,
#  'unconstitutional': 2,
#  'SALT': 2,
#  'provision': 2,
#  'values': 2,
#  'generally': 2,
#  'looking': 2,
#  'CNBC': 2,
#  'interpreted': 2,
#  'deduction': 2,
#  'burden': 2,
#  'effect': 2,
#  'legislation': 2,
#  'discriminate': 2,
#  'blue': 2,
#  'particularly': 2,
#  'Callahan': 2,
#  'noted': 2,
#  'lawsuit': 2,
#  'School': 2,
#  'paper': 2,
#  'shifting': 2,
#  'businesses': 2,
#  'employer': 2,
#  'benefits': 2,
#  'make': 2,
#  'believes': 2,
#  'concerns': 2,
#  'aware': 2,
#  'really': 2,
#  'kept': 2,
#  'spent': 2,
#  'Commerce': 2,
#  'North': 2,
#  'testing': 2,
#  'NAFTA': 2,
#  'Canadian': 2,
#  'Mental': 2,
#  'person': 2,
#  'television': 2,
#  'Police': 2,
#  'incident': 2,
#  'afternoon': 2,
#  'LAPD': 2,
#  'Weise': 2,
#  'box': 2,
#  'opening': 2,
#  'season': 2,
#  'agency': 2,
#  'part': 2,
#  'class': 2,
#  'Bezos': 2,
#  'officer': 2,
#  'Inc': 2,
#  'N': 2,
#  'customers': 2,
#  'million': 2,
#  'leg': 2,
#  'carrier': 2,
#  'teenage girls': 2,
#  'canvassing board': 2,
#  'voter fraud': 2,
#  'armed forces': 2,
#  'estimated ISIS': 2,
#  'held approx': 2,
#  'occupy roughly': 2,
#  'Speaker Paul': 2,
#  'Deferred Action': 2,
#  'Childhood Arrivals': 2,
#  'strategy sessions': 2,
#  'Puerto Rico': 2,
#  'adviser George': 2,
#  'Chain Migration': 2,
#  'pre payment': 2,
#  'retail giant': 2,
#  'operating expenses': 2,
#  'Regulatory Commission': 2,
#  'derailed': 1,
#  'accusations': 1,
#  'vacant': 1,
#  'percentage': 1,
#  'points': 1,
#  'quarter': 1,
#  'century': 1,
#  'held': 1,
#  'sessions': 1,
#  'composed': 1,
#  'Kay': 1,
#  'Ivey': 1,
#  'Marshall': 1,
#  'Seating': 1,
#  'narrow': 1,
#  'chapter': 1,
#  'pledged': 1,
#  'concede': 1,
#  'stood': 1,
#  'fraudulent': 1,
#  'released': 1,
#  'regrets': 1,
#  'outlets': 1,
#  'block': 1,
#  'shortly': 1,
#  'alleged': 1,
#  'potential': 1,
#  'chance': 1,
#  'filing': 1,
#  'Montgomery': 1,
#  'Circuit': 1,
#  'sought': 1,
#  'halt': 1,
#  'ratify': 1,
#  'ask': 1,
#  'recount': 1,
#  'addition': 1,
#  'Fox': 1,
#  'Channel': 1,
#  'complete': 1,
#  'paperwork': 1,
#  'Äúwithin': 1,
#  'timed': 1,
#  'period': 1,
#  'notified': 1,
#  'intention': 1,
#  'Regarding': 1,
#  'cases': 1,
#  'adjudicated': 1,
#  'distanced': 1,
#  'drop': 1,
#  'assault': 1,
#  'dating': 1,
#  'teenagers': 1,
#  'wrongdoing': 1,
#  'able': 1,
#  'independently': 1,
#  'verify': 1,
#  'allowed': 1,
#  'starting': 1,
#  'ordered': 1,
#  'blocked': 1,
#  'Virginia': 1,
#  'rejected': 1,
#  'hold': 1,
#  'requiring': 1,
#  'coming': 1,
#  'litigate': 1,
#  'interim': 1,
#  'occurs': 1,
#  'wait': 1,
#  'DOD': 1,
#  'lawful': 1,
#  'authority': 1,
#  'District': 1,
#  'meantime': 1,
#  'condition': 1,
#  'anonymity': 1,
#  'senior': 1,
#  'implement': 1,
#  'directive': 1,
#  'Feb': 1,
#  'submit': 1,
#  'representing': 1,
#  'currently': 1,
#  'aspiring': 1,
#  'spokeswoman': 1,
#  'Heather': 1,
#  'Babb': 1,
#  'mandated': 1,
#  'accessing': 1,
#  'accession': 1,
#  'Jennifer': 1,
#  'gay': 1,
#  'lesbian': 1,
#  'advocacy': 1,
#  'Äúgreat': 1,
#  'justify': 1,
#  'Civil': 1,
#  'Liberties': 1,
#  'Union': 1,
#  'represent': 1,
#  'plaintiffs': 1,
#  'move': 1,
#  'appealed': 1,
#  'line': 1,
#  'Äúcannot': 1,
#  'burdened': 1,
#  'tremendous': 1,
#  'disruption': 1,
#  'entail': 1,
#  'Baltimore': 1,
#  'D': 1,
#  'C': 1,
#  'Riverside': 1,
#  'blocking': 1,
#  'proceed': 1,
#  'guidelines': 1,
#  'recruitment': 1,
#  'memo': 1,
#  'outlined': 1,
#  'requirements': 1,
#  'specified': 1,
#  'sex': 1,
#  'identified': 1,
#  'undergarments': 1,
#  'wear': 1,
#  'train': 1,
#  'thousands': 1,
#  'might': 1,
#  'accept': 1,
#  'Äúsome': 1,
#  'medically': 1,
#  'Mattis': 1,
#  'postponed': 1,
#  'indefinitely': 1,
#  'steps': 1,
#  'aimed': 1,
#  'rolling': 1,
#  'October': 1,
#  'banning': 1,
#  'workplace': 1,
#  'discrimination': 1,
#  'employees': 1,
#  'era': 1,
#  'position': 1,
#  'rescinded': 1,
#  'guidance': 1,
#  'students': 1,
#  'restroom': 1,
#  'corresponds': 1,
#  'identity': 1,
#  'Fake': 1,
#  'loves': 1,
#  'approval': 1,
#  'foxandfriends': 1,
#  'approximately': 1,
#  'massive': 1,
#  'negative': 1,
#  'coverage': 1,
#  'hoax': 1,
#  'United': 1,
#  'link': 1,
#  'estimates': 1,
#  'via': 1,
#  'Fire': 1,
#  'Rescue': 1,
#  'men': 1,
#  'Firefighters': 1,
#  'paramedics': 1,
#  'responders': 1,
#  'amazing': 1,
#  'dcexaminer': 1,
#  'Arrests': 1,
#  'MS': 1,
#  '2liRH3b': 1,
#  'head': 1,
#  'faction': 1,
#  'huge': 1,
#  'expansion': 1,
#  'Äúfiscal': 1,
#  'restraint': 1,
#  'keeping': 1,
#  'pivot': 1,
#  'ÄúFace': 1,
#  'bracing': 1,
#  'battle': 1,
#  'trying': 1,
#  'linked': 1,
#  'approach': 1,
#  'seek': 1,
#  'proportional': 1,
#  'Äúdiscretionary': 1,
#  'support': 1,
#  'education': 1,
#  'scientific': 1,
#  'environmental': 1,
#  'already': 1,
#  'willing': 1,
#  'say': 1,
#  'ÄòWe': 1,
#  'chairman': 1,
#  'influential': 1,
#  'Freedom': 1,
#  'Caucus': 1,
#  'ÄúNow': 1,
#  'enough': 1,
#  'rationale': 1,
#  'Eventually': 1,
#  'financed': 1,
#  'overhaul': 1,
#  'balloon': 1,
#  'add': 1,
#  'ÄúIt': 1,
#  'interesting': 1,
#  'hear': 1,
#  'responsibility': 1,
#  'require': 1,
#  'borrow': 1,
#  'paid': 1,
#  'generations': 1,
#  'corporations': 1,
#  'rich': 1,
#  'least': 1,
#  'fiscally': 1,
#  'seen': 1,
#  'history': 1,
#  'paying': 1,
#  'insist': 1,
#  'boost': 1,
#  'economy': 1,
#  'growth': 1,
#  'supported': 1,
#  'went': 1,
#  'clear': 1,
#  'radio': 1,
#  'welfare': 1,
#  'reform': 1,
#  'often': 1,
#  'priority': 1,
#  'parlance': 1,
#  'food': 1,
#  'stamps': 1,
#  'housing': 1,
#  'assistance': 1,
#  'Medicare': 1,
#  'Medicaid': 1,
#  'insurance': 1,
#  'elderly': 1,
#  'disabled': 1,
#  'assist': 1,
#  'needy': 1,
#  'seized': 1,
#  'remarks': 1,
#  'try': 1,
#  'goals': 1,
#  'approve': 1,
#  'prevent': 1,
#  'shutdown': 1,
#  'leverage': 1,
#  'narrowly': 1,
#  'tackling': 1,
#  'expiration': 1,
#  'Action': 1,
#  'provides': 1,
#  'messages': 1,
#  'proposed': 1,
#  'exchange': 1,
#  'agreeing': 1,
#  'Debbie': 1,
#  'Dingell': 1,
#  'favor': 1,
#  'linking': 1,
#  'objectives': 1,
#  'clean': 1,
#  'discuss': 1,
#  'Rick': 1,
#  'Scott': 1,
#  'emergency': 1,
#  'far': 1,
#  'exceeded': 1,
#  'requested': 1,
#  'Together': 1,
#  'AMERICA': 1,
#  '2lnpKaq': 1,
#  'East': 1,
#  'COLDEST': 1,
#  'Eve': 1,
#  'record': 1,
#  'Perhaps': 1,
#  'old': 1,
#  'Global': 1,
#  'Warming': 1,
#  'Bundle': 1,
#  'Vanity': 1,
#  'bending': 1,
#  'backwards': 1,
#  'apologizing': 1,
#  'minor': 1,
#  'Crooked': 1,
#  'H': 1,
#  'Anna': 1,
#  'Wintour': 1,
#  'Amb': 1,
#  'St': 1,
#  'fundraiser': 1,
#  'CH': 1,
#  'grief': 1,
#  'begging': 1,
#  'forgiveness': 1,
#  'dirt': 1,
#  'conversation': 1,
#  'Alexander': 1,
#  'Downer': 1,
#  'London': 1,
#  'driving': 1,
#  'factor': 1,
#  'behind': 1,
#  'open': 1,
#  'counter': 1,
#  'came': 1,
#  'leaked': 1,
#  'began': 1,
#  'appearing': 1,
#  'propelled': 1,
#  'friendly': 1,
#  'Dutch': 1,
#  'Chicago': 1,
#  'energy': 1,
#  'pleaded': 1,
#  'guilty': 1,
#  'Oct': 1,
#  'lying': 1,
#  'ties': 1,
#  'alleging': 1,
#  'Äúextremely': 1,
#  'limited': 1,
#  'helped': 1,
#  'Egyptian': 1,
#  'Abdel': 1,
#  'Fattah': 1,
#  'al': 1,
#  'Sisi': 1,
#  'outline': 1,
#  'speech': 1,
#  'Robert': 1,
#  'respond': 1,
#  'Ty': 1,
#  'Cobb': 1,
#  'ÄúOut': 1,
#  'respect': 1,
#  'commenting': 1,
#  'prominent': 1,
#  'Lindsey': 1,
#  'serves': 1,
#  'judiciary': 1,
#  'carry': 1,
#  'go': 1,
#  'forward': 1,
#  'conducted': 1,
#  'influence': 1,
#  'Face': 1,
#  'ÄúAnd': 1,
#  'let': 1,
#  'Mr': 1,
#  'guy': 1,
#  'interfered': 1,
#  'co': 1,
#  'ordinated': 1,
#  'effort': 1,
#  'loomed': 1,
#  'sign': 1,
#  'receding': 1,
#  'prepares': 1,
#  'power': 1,
#  'intensified': 1,
#  'rhetoric': 1,
#  'accusing': 1,
#  'bias': 1,
#  'seemed': 1,
#  'Äúgoing': 1,
#  'focus': 1,
#  'multiple': 1,
#  'inquiries': 1,
#  'Three': 1,
#  'investigating': 1,
#  'earlier': 1,
#  'launched': 1,
#  'convicted': 1,
#  'indicted': 1,
#  'deny': 1,
#  'Kremlin': 1,
#  'still': 1,
#  'examination': 1,
#  'compiled': 1,
#  'spy': 1,
#  'Christopher': 1,
#  'Steele': 1,
#  'inquiry': 1,
#  'triggered': 1,
#  ...}

# %%
prcessed2=WordCloud().process_text(alltextfake)
sortedfreqfake={k: v for k, v in sorted(prcessed2.items(), key=lambda item: -item[1])}
sortedfreqfake
# Out:
# {'s': 59,
#  'Trump': 38,
#  'will': 32,
#  'December': 29,
#  'people': 26,
#  'Trump s': 19,
#  'president': 18,
#  'one': 16,
#  't': 16,
#  'year': 16,
#  'day': 16,
#  'know': 14,
#  'Donald Trump': 14,
#  'Getty Images': 14,
#  'well': 13,
#  'even': 13,
#  'pic twitter': 13,
#  'Republican': 11,
#  'said': 11,
#  'u': 11,
#  'New Year': 11,
#  'now': 10,
#  'see': 10,
#  'media': 10,
#  're': 10,
#  'Photo': 10,
#  'American': 10,
#  'look': 10,
#  'golf': 10,
#  'many': 9,
#  'man': 9,
#  'America': 9,
#  'former': 9,
#  'nothing': 9,
#  'think': 9,
#  'done': 9,
#  'Disney': 9,
#  'Obama': 9,
#  'investigation': 9,
#  'right': 8,
#  'come': 8,
#  'Clarke': 8,
#  'way': 8,
#  'say': 8,
#  'tax': 8,
#  'never': 7,
#  'go': 7,
#  'called': 7,
#  'hope': 7,
#  'report': 7,
#  'country': 7,
#  'GOP': 7,
#  'kind': 7,
#  'need': 7,
#  'Happy': 7,
#  'message': 7,
#  'Featured image': 7,
#  'image via': 7,
#  'FAKE NEWS': 7,
#  'always': 6,
#  'email': 6,
#  'continue': 6,
#  'make': 6,
#  'time': 6,
#  'months': 6,
#  'friends': 6,
#  'back': 6,
#  'House': 6,
#  'Today': 6,
#  'Senate': 6,
#  'Papadopoulos': 6,
#  'ad': 6,
#  'Christmas': 6,
#  'doesn t': 6,
#  'campaign': 5,
#  'white': 5,
#  'course': 5,
#  'police': 5,
#  'trying': 5,
#  'David': 5,
#  'though': 5,
#  'New': 5,
#  'far': 5,
#  'according': 5,
#  'office': 5,
#  'state': 5,
#  'place': 5,
#  'scam': 5,
#  'long': 5,
#  'truth': 5,
#  'something': 5,
#  'McConnell': 5,
#  'order': 5,
#  'much': 5,
#  'without': 5,
#  'll': 5,
#  'want': 5,
#  'matter': 5,
#  'wish': 5,
#  'tweet': 5,
#  'families': 5,
#  'actually': 5,
#  'McCabe': 5,
#  'code': 5,
#  'Francis': 5,
#  'official': 5,
#  'isn t': 5,
#  'https t': 5,
#  't co': 5,
#  'tax bill': 5,
#  'Hillary Clinton': 5,
#  'Donald J': 5,
#  'J Trump': 5,
#  'Trump realDonaldTrump': 5,
#  'realDonaldTrump December': 5,
#  'Andrew McCabe': 5,
#  'Christopher Ingraham': 5,
#  'Ingraham _cingraham': 5,
#  '_cingraham December': 5,
#  'First': 4,
#  'bad': 4,
#  'number': 4,
#  'really': 4,
#  'CEO': 4,
#  'BREAKING': 4,
#  'thing': 4,
#  'Black': 4,
#  'eye': 4,
#  'attacked': 4,
#  'better': 4,
#  'LYING': 4,
#  'lie': 4,
#  'decision': 4,
#  'charge': 4,
#  'someone': 4,
#  'made': 4,
#  'break': 4,
#  'still': 4,
#  'enough': 4,
#  'yet': 4,
#  'getting': 4,
#  'Instead': 4,
#  'making': 4,
#  'used': 4,
#  'given': 4,
#  'Let': 4,
#  'bill': 4,
#  'Congress': 4,
#  'saying': 4,
#  'coverage': 4,
#  'went': 4,
#  'kook': 4,
#  'attempt': 4,
#  'take': 4,
#  'problem': 4,
#  'wealthy': 4,
#  'good': 4,
#  'Watch': 4,
#  'going': 4,
#  'Obamacare': 4,
#  'may': 4,
#  'Democratic': 4,
#  'd': 4,
#  'term': 4,
#  'full': 4,
#  'Russian': 4,
#  'Australian': 4,
#  'leave': 4,
#  'great': 4,
#  'word': 4,
#  'including': 4,
#  'change': 4,
#  'living': 4,
#  'paycheck': 4,
#  'cops': 4,
#  'away': 4,
#  'fact': 4,
#  'website': 4,
#  'coding': 4,
#  'issue': 4,
#  'Pope': 4,
#  'Jerusalem': 4,
#  'Jesus': 4,
#  'home': 4,
#  'search warrant': 4,
#  'lib media': 4,
#  'December 2017He': 4,
#  'New York': 4,
#  'Paul Ryan': 4,
#  'tax cut': 4,
#  'FBI Deputy': 4,
#  'Deputy Director': 4,
#  'Director Andrew': 4,
#  'presidency': 3,
#  'public': 3,
#  'national': 3,
#  'racist': 3,
#  'business': 3,
#  'pizza': 3,
#  'John': 3,
#  'decided': 3,
#  'Schnatter': 3,
#  'political': 3,
#  'especially': 3,
#  'anything': 3,
#  'run': 3,
#  'nation': 3,
#  'revealed': 3,
#  'administration': 3,
#  'stop': 3,
#  'FBI': 3,
#  'Internet': 3,
#  'smear': 3,
#  'tweeted': 3,
#  'MAGA': 3,
#  'twitter': 3,
#  'didn': 3,
#  'give': 3,
#  'won': 3,
#  '2017I': 3,
#  '2017You': 3,
#  'stand': 3,
#  'Chris': 3,
#  'jail': 3,
#  'Robert': 3,
#  'old': 3,
#  'thought': 3,
#  'point': 3,
#  'plan': 3,
#  'bar': 3,
#  'already': 3,
#  'immigrants': 3,
#  'document': 3,
#  'top': 3,
#  'noted': 3,
#  'Miller': 3,
#  'meeting': 3,
#  'page': 3,
#  'along': 3,
#  'information': 3,
#  'talking': 3,
#  've': 3,
#  'different': 3,
#  'Graham': 3,
#  'opinion': 3,
#  'video': 3,
#  'M': 3,
#  'using': 3,
#  'f': 3,
#  'election': 3,
#  'focus': 3,
#  'savings': 3,
#  'million': 3,
#  'children': 3,
#  'stay': 3,
#  'angry': 3,
#  'taking': 3,
#  'democracy': 3,
#  'added': 3,
#  'NPR': 3,
#  'completely': 3,
#  'entitlement': 3,
#  'Russia': 3,
#  'wine': 3,
#  'Clinton': 3,
#  'boy': 3,
#  'don': 3,
#  'set': 3,
#  'Mr': 3,
#  'haters': 3,
#  'supporters': 3,
#  '2017Trump': 3,
#  'work': 3,
#  'got': 3,
#  'working': 3,
#  'might': 3,
#  'vote': 3,
#  'face': 3,
#  'shared': 3,
#  'wide': 3,
#  'name': 3,
#  'camera': 3,
#  'young': 3,
#  'spent': 3,
#  'following': 3,
#  'James': 3,
#  'deleted': 3,
#  'wife': 3,
#  'July': 3,
#  'believe': 3,
#  'little': 3,
#  'thanking': 3,
#  'best': 3,
#  'track': 3,
#  'display': 3,
#  'land': 3,
#  'child': 3,
#  'autocrat': 3,
#  'Brennan': 3,
#  'Papa John': 3,
#  'Pool Getty': 3,
#  'Lindsey Graham': 3,
#  'Mitch McConnell': 3,
#  'middle class': 3,
#  'former reality': 3,
#  'reality show': 3,
#  'show star': 3,
#  'enemies haters': 3,
#  'dishonest Fake': 3,
#  'two states': 3,
#  'Angela Williams': 3,
#  'Williams son': 3,
#  'United Nations': 3,
#  'supremacist': 2,
#  'gets': 2,
#  'color': 2,
#  'favorite': 2,
#  'targets': 2,
#  'players': 2,
#  'exercise': 2,
#  'protest': 2,
#  'person': 2,
#  'racism': 2,
#  'orange': 2,
#  'founder': 2,
#  'chain': 2,
#  'history': 2,
#  'sales': 2,
#  'dropped': 2,
#  'pay': 2,
#  'line': 2,
#  'longer': 2,
#  'step': 2,
#  'NFL': 2,
#  '2017The': 2,
#  'allowed': 2,
#  'realize': 2,
#  'often': 2,
#  'support': 2,
#  'future': 2,
#  'fabric': 2,
#  'rest': 2,
#  'Milwaukee': 2,
#  'Sheriff': 2,
#  'fellow': 2,
#  'later': 2,
#  'calling': 2,
#  'UNINTIMIDATED': 2,
#  'discredit': 2,
#  'designed': 2,
#  'silence': 2,
#  'poke': 2,
#  'nose': 2,
#  'TASTE': 2,
#  'BLOOD': 2,
#  'bully': 2,
#  'newspaper': 2,
#  'mean': 2,
#  'hat': 2,
#  'seem': 2,
#  '2017Are': 2,
#  'fingers': 2,
#  'died': 2,
#  'short': 2,
#  'guy': 2,
#  'sure': 2,
#  'water': 2,
#  'another': 2,
#  'frustration': 2,
#  'article': 2,
#  'visas': 2,
#  'issued': 2,
#  'looked': 2,
#  'fool': 2,
#  'began': 2,
#  'advisor': 2,
#  'Stephen': 2,
#  'Cabinet': 2,
#  'included': 2,
#  'Afghanistan': 2,
#  'Haiti': 2,
#  'Nigeria': 2,
#  'room': 2,
#  'others': 2,
#  'research': 2,
#  'turned': 2,
#  'delivered': 2,
#  'Mueller': 2,
#  'members': 2,
#  'passed': 2,
#  'quite': 2,
#  'rather': 2,
#  'exactly': 2,
#  'hasn': 2,
#  'unfit': 2,
#  'job': 2,
#  'press': 2,
#  'endless': 2,
#  'label': 2,
#  'fit': 2,
#  'mouth': 2,
#  'exact': 2,
#  'Abigail': 2,
#  'heiress': 2,
#  'poor': 2,
#  'inequality': 2,
#  'Ryan': 2,
#  'trickle': 2,
#  'current': 2,
#  'system': 2,
#  'proposal': 2,
#  'common': 2,
#  'bomb': 2,
#  'insist': 2,
#  'cut': 2,
#  'taxes': 2,
#  'Medicaid': 2,
#  'education': 2,
#  'killing': 2,
#  'insurance': 2,
#  'wrote': 2,
#  'pass': 2,
#  'free': 2,
#  'reach': 2,
#  'lot': 2,
#  'voting': 2,
#  'mind': 2,
#  'benefit': 2,
#  'interest': 2,
#  'citizens': 2,
#  'reform': 2,
#  'repealed': 2,
#  'true': 2,
#  'Leader': 2,
#  'told': 2,
#  'bipartisan': 2,
#  'become': 2,
#  'repeal': 2,
#  'move': 2,
#  'Sen': 2,
#  'allow': 2,
#  'last': 2,
#  'Committee': 2,
#  'Christopher': 2,
#  'dossier': 2,
#  'Department': 2,
#  'Justice': 2,
#  'knowledge': 2,
#  'wasn': 2,
#  'role': 2,
#  'Coffee': 2,
#  'two': 2,
#  'world': 2,
#  'team': 2,
#  'presidential': 2,
#  'nominee': 2,
#  'unclear': 2,
#  'direct': 2,
#  'badly': 2,
#  'couldn': 2,
#  'enemies': 2,
#  'smarter': 2,
#  'Healthy': 2,
#  'expect': 2,
#  'lack': 2,
#  'include': 2,
#  'hate': 2,
#  '2017Who': 2,
#  'uses': 2,
#  'Love': 2,
#  'clearly': 2,
#  'becoming': 2,
#  'voted': 2,
#  'wrong': 2,
#  'family': 2,
#  'per': 2,
#  'significant': 2,
#  'false': 2,
#  'claim': 2,
#  'struggling': 2,
#  'next': 2,
#  'either': 2,
#  'case': 2,
#  'Alabama': 2,
#  'son': 2,
#  'unacceptable': 2,
#  'custody': 2,
#  'supposed': 2,
#  'post': 2,
#  'body': 2,
#  'beating': 2,
#  'Hell': 2,
#  'paid': 2,
#  'game': 2,
#  'retire': 2,
#  'week': 2,
#  'regarding': 2,
#  'leakin': 2,
#  'Comey': 2,
#  'Phony': 2,
#  'illegally': 2,
#  'Puppets': 2,
#  'fight': 2,
#  'favor': 2,
#  'watching': 2,
#  'Policies': 2,
#  'Thank': 2,
#  'Merry': 2,
#  'Nobody': 2,
#  'propaganda': 2,
#  'pain': 2,
#  'row': 2,
#  'blasted': 2,
#  'played': 2,
#  'total': 2,
#  'weird': 2,
#  'reference': 2,
#  'error': 2,
#  '2017That': 2,
#  'RNC': 2,
#  'clear': 2,
#  'UPDATE': 2,
#  'admin': 2,
#  'idea': 2,
#  'exchange': 2,
#  'led': 2,
#  'recognize': 2,
#  'capital': 2,
#  'forced': 2,
#  'inn': 2,
#  'Bethlehem': 2,
#  'Mary': 2,
#  'Joseph': 2,
#  'couple': 2,
#  'heart': 2,
#  'behind': 2,
#  'footsteps': 2,
#  'democracies': 2,
#  'Autocracy': 2,
#  'discrediting': 2,
#  'possibly': 2,
#  'usually': 2,
#  'O': 2,
#  'threat': 2,
#  'sharp stick': 2,
#  'bitch slap': 2,
#  'scum bags': 2,
#  'bags til': 2,
#  'Jr SheriffClarke': 2,
#  'travel ban': 2,
#  'private jet': 2,
#  'Alexander Downer': 2,
#  'rapidly grows': 2,
#  'grows stronger': 2,
#  'centerpiece': 1,
#  'feuds': 1,
#  'involve': 1,
#  'Football': 1,
#  'League': 1,
#  'dare': 1,
#  'Amendment': 1,
#  'kneeling': 1,
#  'anthem': 1,
#  'brutality': 1,
#  'figured': 1,
#  'overlord': 1,
#  'elected': 1,
#  'side': 1,
#  'plus': 1,
#  'sucks': 1,
#  'complain': 1,
#  'protesting': 1,
#  'Turns': 1,
#  'corporations': 1,
#  'bottom': 1,
#  'hack': 1,
#  'announcement': 1,
#  'criticized': 1,
#  'AP': 1,
#  'APBusiness': 1,
#  'certainly': 1,
#  'dire': 1,
#  'consequences': 1,
#  'garner': 1,
#  'presume': 1,
#  'goal': 1,
#  'whether': 1,
#  'pressure': 1,
#  'shareholders': 1,
#  'outcry': 1,
#  'boycotts': 1,
#  'stepping': 1,
#  'gone': 1,
#  'perhaps': 1,
#  'company': 1,
#  'inclusive': 1,
#  'diverse': 1,
#  'call': 1,
#  'guiding': 1,
#  'symbol': 1,
#  'Statue': 1,
#  'Liberty': 1,
#  'bigots': 1,
#  'past': 1,
#  'survive': 1,
#  'present': 1,
#  'Rob': 1,
#  'Kim': 1,
#  'Friday': 1,
#  'considered': 1,
#  'Homeland': 1,
#  'Security': 1,
#  'Secretary': 1,
#  'scandal': 1,
#  'January': 1,
#  'brief': 1,
#  'plane': 1,
#  'passenger': 1,
#  'Dan': 1,
#  'detained': 1,
#  'reason': 1,
#  'whatsoever': 1,
#  'except': 1,
#  'maybe': 1,
#  'feelings': 1,
#  'hurt': 1,
#  'messaged': 1,
#  'deplaned': 1,
#  'executed': 1,
#  'copies': 1,
#  'XtZW5PdU2b': 1,
#  'ANTIDOTE': 1,
#  'Punch': 1,
#  'attention': 1,
#  'neverbackdown': 1,
#  'T2NY2psHCR': 1,
#  'local': 1,
#  'chose': 1,
#  'file': 1,
#  'filed': 1,
#  'zcbyc4Wp5b': 1,
#  'KeithLeBlanc': 1,
#  'KeithLeBlanc63': 1,
#  'Village': 1,
#  'aren': 1,
#  'implicated': 1,
#  'Kirk': 1,
#  'Ketchum': 1,
#  'kirkketchum': 1,
#  '2017Slaw': 1,
#  'baked': 1,
#  'potatoes': 1,
#  'French': 1,
#  'fries': 1,
#  'fWfXsZupxy': 1,
#  'ALT': 1,
#  'Immigration': 1,
#  'ALT_uscis': 1,
#  '2017pic': 1,
#  'ymsOBLjfxU': 1,
#  'Pendulum': 1,
#  'Swinger': 1,
#  'PendulumSwngr': 1,
#  'fun': 1,
#  'Jackson': 1,
#  'ChrisCJackson': 1,
#  'masterful': 1,
#  'pshop': 1,
#  'tire': 1,
#  'steely': 1,
#  'resolve': 1,
#  'visible': 1,
#  'dWr5k8ZEZV': 1,
#  'Mohney': 1,
#  'chrismohney': 1,
#  'indicating': 1,
#  'dipshit': 1,
#  'Ike': 1,
#  'Barinholtz': 1,
#  'ikebarinholtz': 1,
#  '2017ROFL': 1,
#  'tough': 1,
#  'flair': 1,
#  'ulCFddhkdy': 1,
#  'KellMeCrazy': 1,
#  'Kel_MoonFace': 1,
#  'edgy': 1,
#  'buddy': 1,
#  'SMH': 1,
#  'MRSSMH2': 1,
#  'Applebees': 1,
#  'Aaron': 1,
#  'feltrrr2': 1,
#  'earn': 1,
#  'relevant': 1,
#  'badge': 1,
#  'CircusRebel': 1,
#  'CircusDrew': 1,
#  '2017make': 1,
#  'hydrate': 1,
#  'drink': 1,
#  'rumored': 1,
#  'prisoners': 1,
#  'denied': 1,
#  'prison': 1,
#  'Klinc': 1,
#  'RobertKlinc1': 1,
#  '2017Terrill': 1,
#  'Thomas': 1,
#  'thirst': 1,
#  'County': 1,
#  'cell': 1,
#  'April': 1,
#  'victim': 1,
#  'homicide': 1,
#  'repeated': 1,
#  'Spencer': 1,
#  'Platt': 1,
#  'wake': 1,
#  'court': 1,
#  'derailed': 1,
#  'Muslims': 1,
#  'entering': 1,
#  'United': 1,
#  'published': 1,
#  'Saturday': 1,
#  'morning': 1,
#  'detailing': 1,
#  'goes': 1,
#  'June': 1,
#  'stomped': 1,
#  'Oval': 1,
#  'furious': 1,
#  'implemented': 1,
#  'fully': 1,
#  'fumed': 1,
#  'rate': 1,
#  'broad': 1,
#  'pronouncements': 1,
#  'reading': 1,
#  'handed': 1,
#  'listed': 1,
#  'sensing': 1,
#  'pattern': 1,
#  'expressed': 1,
#  'dismay': 1,
#  'witnesses': 1,
#  'spoke': 1,
#  'condition': 1,
#  'anonymity': 1,
#  'interviewed': 1,
#  'three': 1,
#  'dozen': 1,
#  'faults': 1,
#  'read': 1,
#  'terrorist': 1,
#  'haven': 1,
#  'huts': 1,
#  'saw': 1,
#  'glory': 1,
#  'AIDS': 1,
#  'Despite': 1,
#  'extensive': 1,
#  'denies': 1,
#  'language': 1,
#  'blatant': 1,
#  'nationalism': 1,
#  'surprise': 1,
#  'Freedom': 1,
#  'Act': 1,
#  'request': 1,
#  'question': 1,
#  'statements': 1,
#  'printed': 1,
#  'inline': 1,
#  'commentary': 1,
#  'punctuate': 1,
#  'anger': 1,
#  'responsible': 1,
#  'Carnage': 1,
#  'speech': 1,
#  'inauguration': 1,
#  'menace': 1,
#  'represent': 1,
#  'indictments': 1,
#  'speak': 1,
#  'Kleponis': 1,
#  'Party': 1,
#  'sheer': 1,
#  'obsequiousness': 1,
#  'analysis': 1,
#  'discussion': 1,
#  'praising': 1,
#  'grand': 1,
#  'achievement': 1,
#  'increasingly': 1,
#  'sounded': 1,
#  'general': 1,
#  'changed': 1,
#  'portraying': 1,
#  'wouldn': 1,
#  'weren': 1,
#  'telling': 1,
#  'concerns': 1,
#  'Jake': 1,
#  'Tapper': 1,
#  'notes': 1,
#  'labeled': 1,
#  'odd': 1,
#  'clip': 1,
#  'concerned': 1,
#  'crazy': 1,
#  'hIxs3DciO8': 1,
#  'Tomthunkit': 1,
#  'TomthunkitsMind': 1,
#  '2017There': 1,
#  'parroted': 1,
#  'describe': 1,
#  'Freudian': 1,
#  'slip': 1,
#  'screen': 1,
#  'capture': 1,
#  'brass': 1,
#  'ovaries': 1,
#  'profit': 1,
#  'cking': 1,
#  'penned': 1,
#  'op': 1,
#  'ed': 1,
#  'USA': 1,
#  'rips': 1,
#  'cognizant': 1,
#  'income': 1,
#  'wealth': 1,
#  'Bob': 1,
#  'Corker': 1,
#  'dammit': 1,
#  'Ronald': 1,
#  'Reagan': 1,
#  'gap': 1,
#  'rich': 1,
#  'grown': 1,
#  'dramatically': 1,
#  'economics': 1,
#  'cause': 1,
#  'writes': 1,
#  'brought': 1,
#  'sharper': 1,
#  'overhaul': 1,
#  'burdensome': 1,
#  'middle': 1,
#  'class': 1,
#  'decreasing': 1,
#  'responsibility': 1,
#  'contribute': 1,
#  'meager': 1,
#  'offset': 1,
#  'losses': 1,
#  'elsewhere': 1,
#  'deductions': 1,
#  'loss': 1,
#  'Medicare': 1,
#  'less': 1,
#  'funding': 1,
#  'chopping': 1,
#  'block': 1,
#  'provide': 1,
#  'owners': 1,
#  'health': 1,
#  'suffocating': 1,
#  'dying': 1,
#  'infrastructure': 1,
#  'debt': 1,
#  'least': 1,
#  'trillion': 1,
#  'bigger': 1,
#  'social': 1,
#  'mobility': 1,
#  'continued': 1,
#  'able': 1,
#  'comfortably': 1,
#  'strike': 1,
#  'fair': 1,
#  'thankyouverymuch': 1,
#  'written': 1,
#  'looking': 1,
#  'nightmare': 1,
#  'Pirates': 1,
#  'Caribbean': 1,
#  'life': 1,
#  'E5bmcI83mU': 1,
#  'NowThis': 1,
#  'nowthisnews': 1,
#  'bunch': 1,
#  'advocating': 1,
#  'self': 1,
#  'greater': 1,
#  'anarchy': 1,
#  'start': 1,
#  'acting': 1,
#  'personal': 1,
#  'heist': 1,
#  'Ralph': 1,
#  'Orlowski': 1,
#  'Burda': 1,
#  'seven': 1,
#  'viable': 1,
#  'replacement': 1,
#  'failed': 1,
#  'miserably': 1,
#  'victory': 1,
#  'lap': 1,
#  'gifting': 1,
#  'Wednesday': 1,
#  'essentially': 1,
#  'eradicate': 1,
#  'signature': 1,
#  'legislation': 1,
#  'offering': 1,
#  'alternative': 1,
#  'Majority': 1,
#  'pivot': 1,
#  'cooperative': 1,
#  'DOA': 1,
#  'obviously': 1,
#  'unable': 1,
#  'replace': 1,
#  'Kentucky': 1,
#  'probably': 1,
#  'stabilizing': 1,
#  'marketplaces': 1,
#  'keep': 1,
#  'premiums': 1,
#  'skyrocketing': 1,
#  'early': 1,
#  'promise': 1,
#  'moderate': 1,
#  'Susan': 1,
#  'Collins': 1,
#  'Maine': 1,
#  'broke': 1,
#  'Speaker': 1,
#  'Wis': 1,
#  'approach': 1,
#  'paring': 1,
#  'spending': 1,
#  'programs': 1,
#  'food': 1,
#  'stamps': 1,
#  'interested': 1,
#  'budget': 1,
#  'rules': 1,
#  'consultation': 1,
#  'Democrats': 1,
#  'sustained': 1,
#  'almost': 1,
#  'agenda': 1,
#  'join': 1,
#  'tackle': 1,
#  'coming': 1,
#  'destroying': 1,
#  'recall': 1,
#  'priority': 1,
#  'hoping': 1,
#  'Funny': 1,
#  'Chip': 1,
#  'Somodevilla': 1,
#  'Intelligence': 1,
#  'Chairman': 1,
#  'Devin': 1,
#  'Nunes': 1,
#  'assumption': 1,
#  'Steele': 1,
#  'prompted': 1,
#  'lashing': 1,
#  'protect': 1,
#  'happens': 1,
#  'started': 1,
#  'obtained': 1,
#  'adviser': 1,
#  'George': 1,
#  'drunk': 1,
#  'opposition': 1,
#  'covfefe': 1,
#  'alleged': 1,
#  'larger': 1,
#  'none': 1,
#  'damning': 1,
#  'drunken': 1,
#  'help': 1,
#  'arrange': 1,
#  'Abdel': 1,
#  'Fattah': 1,
#  'el': 1,
#  'Sisi': 1,
#  'Egypt': 1,
#  'known': 1,
#  'aide': 1,
#  'ran': 1,
#  'merely': 1,
#  ...}

# %%
plt.figure(figsize=(40,10))
plt.xticks(rotation=50)
plt.bar(list(sortedfreqreal.keys())[:50],list(sortedfreqreal.values())[:50], color='darkblue')
# Out:
# <BarContainer object of 50 artists>

# %%
plt.figure(figsize=(30,10))
plt.xticks(rotation=50)
plt.bar(list(sortedfreqfake.keys())[:50],list(sortedfreqfake.values())[:50], color='purple')
# Out:
# <BarContainer object of 50 artists>

# %% [markdown]
# # Preprocessing

# %% [markdown]
# data cleaning
#
# - remove tagging people (@kdhefjw)
# - remove url
# - remove things that are not exactly url but contain slash (pic.twitter.com/wiQSQNNzw0)
# - remove (Rueters) which would indicate real news
# - remove punctuations
# - remove digits
# - remove stop words
# - stem words

# %%
# remove punctuation, stopwords

stemmer = PorterStemmer()

def clean(text):
    if "(Reuters)" in text: # real news contains this identifier sometimes
        text=text.split("(Reuters)")[1]
    text=re.sub(r'@[^s]*', '', text)
    text=re.sub(r'https?://\S+|www\.\S+', '', text)
    text=" ".join([wd for wd in text.split() if "\\" not in wd and "/" not in wd and wd not in stopwords.words('english')])
    text="".join([c for c in text if c not in string.punctuation])
    text="".join([c for c in text if not c.isdigit()])
    text=re.sub('[^a-zA-z\s]', '', text)
    text=text.lower()
    text=" ".join([stemmer.stem(wd) for wd in text.split()])
    return text


print(clean(real["text"][10]))
real["text"][10]
# Out:
# alabama offici thursday certifi democrat doug jone winner state us senat race state judg deni challeng republican roy moor whose campaign derail accus sexual misconduct teenag girl jone vacant seat vote percentag point elect offici said that made first democrat quarter centuri win senat seat alabama the seat previous held republican jeff session tap us presid donald trump attorney gener a state canvass board compos alabama secretari state john merril governor kay ivey attorney gener steve marshal certifi elect result seat jone narrow republican major senat seat in statement jone call victori a new chapter pledg work parti moor declin conced defeat even trump urg so he stood claim fraudul elect statement releas certif said regret media outlet report an alabama judg deni moor request block certif result dec elect decis shortli canvass board met moor challeng alleg potenti voter fraud deni chanc victori hi file wednesday montgomeri circuit court sought halt meet schedul ratifi jone win thursday moor could ask recount addit possibl court challeng merril said interview fox news channel he would complet paperwork within time period show money challeng merril said weve notifi yet intent that merril said regard claim voter fraud merril told cnn case report weve adjud those we continu that said republican lawmak washington distanc moor call drop race sever women accus sexual assault misconduct date back teenag earli s moor deni wrongdo reuter abl independ verifi alleg
# '(Reuters) - Alabama officials on Thursday certified Democrat Doug Jones the winner of the state‚Äôs U.S. Senate race, after a state judge denied a challenge by Republican Roy Moore, whose campaign was derailed by accusations of sexual misconduct with teenage girls. Jones won the vacant seat by about 22,000 votes, or 1.6 percentage points, election officials said. That made him the first Democrat in a quarter of a century to win a Senate seat in Alabama.  The seat was previously held by Republican Jeff Sessions, who was tapped by U.S. President Donald Trump as attorney general. A state canvassing board composed of Alabama Secretary of State John Merrill, Governor Kay Ivey and Attorney General Steve Marshall certified the election results. Seating Jones will narrow the Republican majority in the Senate to 51 of 100 seats. In a statement, Jones called his victory ‚Äúa new chapter‚Äù and pledged to work with both parties. Moore declined to concede defeat even after Trump urged him to do so. He stood by claims of a fraudulent election in a statement released after the certification and said he had no regrets, media outlets reported. An Alabama judge denied Moore‚Äôs request to block certification of the results of the Dec. 12 election in a decision shortly before the canvassing board met. Moore‚Äôs challenge alleged there had been potential voter fraud that denied him a chance of victory. His filing on Wednesday in the Montgomery Circuit Court sought to halt the meeting scheduled to ratify Jones‚Äô win on Thursday. Moore could ask for a recount, in addition to possible other court challenges, Merrill said in an interview with Fox News Channel. He would have to complete paperwork ‚Äúwithin a timed period‚Äù and show he has the money for a challenge, Merrill said. ‚ÄúWe‚Äôve not been notified yet of their intention to do that,‚Äù Merrill said. Regarding the claim of voter fraud, Merrill told CNN that more than 100 cases had been reported. ‚ÄúWe‚Äôve adjudicated more than 60 of those. We will continue to do that,‚Äù he said.  Republican lawmakers in Washington had distanced themselves from Moore and called for him to drop out of the race after several women accused him of sexual assault or misconduct dating back to when they were teenagers and he was in his early 30s.  Moore has denied wrongdoing and Reuters has not been able to independently verify the allegations. '

# %% [markdown]
# ## cleaning data

# %%
real["isfake"]=0
fake["isfake"]=1

allnews = pd.concat([real, fake]) ## Combine the two datasets (real and Fake)

# Takes about 2 hours to clean this dataset, use the already cleaned file instead of running this every time 
# Cleans dataset Line by Line using Lambda function for every line (text) : perform clean functionon the tweet
allnews['text'] = allnews['text'].apply(lambda text: clean(text))

pd.DataFrame.to_csv(allnews, "cleaned_news_text_new.csv", index=False)

# %%
cleanedtext=pd.read_csv("cleaned_news_text_new.csv")

# %%
cleanedtext
# Out:
#                                                 title  \
# 0   As U.S. budget fight looms, Republicans flip t...
# 1   U.S. military to accept transgender recruits o...
# 2   Senior U.S. Republican senator: 'Let Mr. Muell...
# 3   FBI Russia probe helped by Australian diplomat...
# 4   Trump wants Postal Service to charge 'much mor...
# 5   White House, Congress prepare for talks on spe...
# 6   Trump says Russia probe will be fair, but time...
# 7   Factbox: Trump on Twitter (Dec 29) - Approval ...
# 8          Trump on Twitter (Dec 28) - Global Warming
# 9   Alabama official to certify Senator-elect Jone...
# 10  Jones certified U.S. Senate winner despite Moo...
# 11  New York governor questions the constitutional...
# 12  Factbox: Trump on Twitter (Dec 28) - Vanity Fa...
# 13     Trump on Twitter (Dec 27) - Trump, Iraq, Syria
# 14  Man says he delivered manure to Mnuchin to pro...
# 15   Donald Trump Sends Out Embarrassing New Year‚...
# 16   Drunk Bragging Trump Staffer Started Russian ...
# 17   Sheriff David Clarke Becomes An Internet Joke...
# 18   Trump Is So Obsessed He Even Has Obama‚Äôs Na...
# 19   Pope Francis Just Called Out Donald Trump Dur...
# 20   Racist Alabama Cops Brutalize Black Boy While...
# 21   Fresh Off The Golf Course, Trump Lashes Out A...
# 22   Trump Said Some INSANELY Racist Stuff Inside ...
# 23   Former CIA Director Slams Trump Over UN Bully...
# 24   WATCH: Brand-New Pro-Trump Ad Features So Muc...
# 25   Papa John‚Äôs Founder Retires, Figures Out Ra...
# 26   WATCH: Paul Ryan Just Told Us He Doesn‚Äôt Ca...
# 27   Bad News For Trump ‚Äî Mitch McConnell Says N...
# 28   WATCH: Lindsey Graham Trashes Media For Portr...
# 29   Heiress To Disney Empire Knows GOP Scammed Us...
#
#                                                  text       subject  \
# 0   the head conserv republican faction us congres...  politicsNews
# 1   transgend peopl allow first time enlist us mil...  politicsNews
# 2   the special counsel investig link russia presi...  politicsNews
# 3   trump campaign advis georg papadopoulo told au...  politicsNews
# 4   presid donald trump call us postal servic frid...  politicsNews
# 5   the white hous said friday set kick talk next ...  politicsNews
# 6   presid donald trump said thursday believ fairl...  politicsNews
# 7   the follow statementswer post verifi twitter a...  politicsNews
# 8   the follow statementswer post verifi twitter a...  politicsNews
# 9   alabama secretari state john merril said certi...  politicsNews
# 10  alabama offici thursday certifi democrat doug ...  politicsNews
# 11  the new us tax code target hightax state may u...  politicsNews
# 12  the follow statementswer post verifi twitter a...  politicsNews
# 13  the follow statementswer post verifi twitter a...  politicsNews
# 14  a man claim person deliv giftwrap packag hors ...  politicsNews
# 15  donald trump wish american happi new year leav...          News
# 16  hous intellig committe chairman devin nune go ...          News
# 17  on friday reveal former milwauke sheriff david...          News
# 18  on christma day donald trump announc would bac...          News
# 19  pope franci use annual christma day messag reb...          News
# 20  the number case cop brutal kill peopl color se...          News
# 21  donald trump spent good portion day golf club ...          News
# 22  in wake yet anoth court decis derail donald tr...          News
# 23  mani peopl rais alarm regard fact donald trump...          News
# 24  just might thought get break watch peopl kiss ...          News
# 25  a centerpiec donald trump campaign presid whit...          News
# 26  republican work overtim tri sell scam tax bill...          News
# 27  republican seven year come viabl replac obamac...          News
# 28  the media talk day trump republican parti scam...          News
# 29  abigail disney heiress brass ovari profit gop ...          News
#
#          date  textlength  isfake
# 0   31-Dec-17        4727       0
# 1   29-Dec-17        4125       0
# 2   31-Dec-17        2825       0
# 3   30-Dec-17        2485       0
# 4   29-Dec-17        5240       0
# 5   29-Dec-17        3725       0
# 6   29-Dec-17        3270       0
# 7   29-Dec-17         858       0
# 8   29-Dec-17         636       0
# 9   28-Dec-17         410       0
# 10  28-Dec-17        2401       0
# 11  28-Dec-17        3883       0
# 12  28-Dec-17         603       0
# 13  28-Dec-17        1208       0
# 14  25-Dec-17        2150       0
# 15  31-Dec-17        2893       1
# 16  31-Dec-17        1898       1
# 17  30-Dec-17        3597       1
# 18  29-Dec-17        2774       1
# 19  25-Dec-17        2346       1
# 20  25-Dec-17        1741       1
# 21  23-Dec-17        2166       1
# 22  23-Dec-17        2224       1
# 23  22-Dec-17        2772       1
# 24  21-Dec-17        1644       1
# 25  21-Dec-17        2003       1
# 26  21-Dec-17        1625       1
# 27  21-Dec-17        2252       1
# 28  20-Dec-17        1579       1
# 29  20-Dec-17        2795       1

# %%
X_train, X_test, y_train, y_test = train_test_split(cleanedtext.dropna()['text'],cleanedtext.dropna()['isfake'],test_size=0.1, random_state=10)#set random state

# %%
X_train.shape
# Out:
# (27,)

# %% [markdown]
# X_test.shape

# %% [markdown]
# vtz=TfidfVectorizer()
# X_train=vtz.fit_transform(X_train)
# X_test=vtz.transform(X_test)

# %%
# print(vtz.get_feature_names()[:10])
# print(vec.toarray()[:10])
print(len(vtz.get_feature_names()))
print(X_train.shape)
print(X_test.shape)
print(cleanedtext.dropna().shape)
# Out:
# 2021
# (27, 2021)
# (3, 2021)
# (30, 6)

# %% [markdown]
# ### Models
# Logistic regression

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train) 
print(lr.score(X_test, y_test))
lr_pred=lr.predict(X_test)
lrcm=confusion_matrix(y_test,lr_pred)
print(lrcm)

# https://medium.com/@dtuk81/confusion-matrix-visualization-fc31e3f30fea
group_names = ['TN','FP','FN','TP']
group_counts = ['{0:0.0f}'.format(value) for value in lrcm.flatten()]
labels = [f'{v1}\n{v2}' for v1, v2 in zip(group_names,group_counts)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(lrcm, annot=labels, fmt='', cmap="GnBu")
# Out:
# 1.0
# [[2 0]
#  [0 1]]

# %% [markdown]
# ### naive bayes

# %%
nb = MultinomialNB()
nb.fit(X_train, y_train)
nb_pred=nb.predict(X_test)
print(nb.score(X_test, y_test))
nb_cm=confusion_matrix(y_test,nb_pred)
print(nb_cm)

# https://medium.com/@dtuk81/confusion-matrix-visualization-fc31e3f30fea
group_names = ['TN','FP','FN','TP']
group_counts = ['{0:0.0f}'.format(value) for value in nb_cm.flatten()]
labels = [f'{v1}\n{v2}' for v1, v2 in zip(group_names,group_counts)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(nb_cm, annot=labels, fmt='', cmap="GnBu")
# Out:
# 1.0
# [[2 0]
#  [0 1]]

# %% [markdown]
# ## SVM

# %%
from sklearn.linear_model import SGDClassifier

svm = SGDClassifier()
svm.fit(X_train, y_train)
svm_pred=svm.predict(X_test)
print(svm.score(X_test, y_test))
svm_cm=confusion_matrix(y_test,svm_pred)
print(svm_cm)

# https://medium.com/@dtuk81/confusion-matrix-visualization-fc31e3f30fea
group_names = ['TN','FP','FN','TP']
group_counts = ['{0:0.0f}'.format(value) for value in svm_cm.flatten()]
labels = [f'{v1}\n{v2}' for v1, v2 in zip(group_names,group_counts)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(svm_cm, annot=labels, fmt='', cmap="GnBu")
# Out:
# 1.0
# [[2 0]
#  [0 1]]

# %% [markdown]
# ### LSTM

# %%
X_train, X_test, y_train, y_test = train_test_split(cleanedtext.dropna()['text'],cleanedtext.dropna()['isfake'],test_size=0.1, random_state=10)#set random state

# %%
tkn = Tokenizer()
tkn.fit_on_texts(X_train.values)
X_train = tkn.texts_to_sequences(X_train.values)
X_train = pad_sequences(X_train)
X_test = tkn.texts_to_sequences(X_test.values)
X_test = pad_sequences(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-d566e92006bd> in <module>
# ----> 1 tkn = Tokenizer()
#       2 tkn.fit_on_texts(X_train.values)
#       3 X_train = tkn.texts_to_sequences(X_train.values)
#       4 X_train = pad_sequences(X_train)
#       5 X_test = tkn.texts_to_sequences(X_test.values)
#
# NameError: name 'Tokenizer' is not defined

# %%
print(X_train.shape, y_train.shape)
# Out:
# (27,) (27,)

# %%
from keras.layers import Bidirectional
model = Sequential()
# tf.keras.layers.Embedding(
#     input_dim,
#     output_dim,
#     input_length=None,
# )
model.add(Embedding(len(tkn.word_index) + 1, 256, input_length = X_train.shape[1]))
model.add(Bidirectional(LSTM(128)))
model.add(Dropout(0.2)) #drop out to try avoid overfitting with too many hidden units
model.add(Dense(64, activation = 'relu'))
model.add(Dense(1,activation='sigmoid')) # final layer activation is sigmoid becuase classifying 1/0
model.compile(loss = 'binary_crossentropy', optimizer='adam',metrics = ['accuracy'])
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-f8c5ac382253> in <module>
#       1 from keras.layers import Bidirectional
# ----> 2 model = Sequential()
#       3 # tf.keras.layers.Embedding(
#       4 #     input_dim,
#       5 #     output_dim,
#
# NameError: name 'Sequential' is not defined

# %%
model.fit(X_train, y_train, epochs=5, batch_size=128)

# %%
score, acc = model.evaluate(X_test, y_test,batch_size=128)
print('accuracy:', acc)

# %%
X=None
X_train=None
y_train=None
cleanedtext=None
pred=model.predict_classes(X_test)
print(pred[:20])

# %%
lstm_cm=confusion_matrix(y_test,pred)
print(lstm_cm)

# https://medium.com/@dtuk81/confusion-matrix-visualization-fc31e3f30fea
group_names = ['TN','FP','FN','TP']
group_counts = ['{0:0.0f}'.format(value) for value in lstm_cm.flatten()]
labels = [f'{v1}\n{v2}' for v1, v2 in zip(group_names,group_counts)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(lstm_cm, annot=labels, fmt='', cmap="GnBu")
