# %%
# Practice Dataset!!

# %%
import pandas as pd

# %%
df_demo = pd.read_csv("CustomerDemographic.csv")
df_trans = pd.read_csv("Transactions.csv")

# %%
# ALL Objects
df_demo.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'default', 'owns_car', 'tenure'],
#       dtype='object')

# %%
df_demo
# Out:
#       customer_id first_name  last_name  gender  \
# 0             720     Darrel      Canet    Male
# 1            1092     Katlin    Creddon  Female
# 2            3410    Merrili    Brittin  Female
# 3            2413      Abbey     Murrow    Male
# 4             658       Donn    Bonnell    Male
# ...           ...        ...        ...     ...
# 3995         3779      Ulick     Daspar       U
# 3996         3883      Nissa     Conrad       U
# 3997         3931      Kylie      Epine       U
# 3998         3935     Teodor  Alfonsini       U
# 3999         3998     Sarene    Woolley       U
#
#       past_3_years_bike_related_purchases        DOB  \
# 0                                      67 2031-10-23
# 1                                      56 2035-08-22
# 2                                      93 2040-09-22
# 3                                      27 2043-08-11
# 4                                      38 2044-01-24
# ...                                   ...        ...
# 3995                                   68        NaT
# 3996                                   35        NaT
# 3997                                   19        NaT
# 3998                                   72        NaT
# 3999                                   60        NaT
#
#                      job_title job_industry_category     wealth_segment  \
# 0           Recruiting Manager                Retail  Affluent Customer
# 1           VP Quality Control                Retail      Mass Customer
# 2                          NaN              Property      Mass Customer
# 3     Environmental Specialist         Manufacturing     High Net Worth
# 4               Tax Accountant         Manufacturing  Affluent Customer
# ...                        ...                   ...                ...
# 3995                       NaN                    IT  Affluent Customer
# 3996           Legal Assistant                    IT      Mass Customer
# 3997                       NaN                    IT     High Net Worth
# 3998                       NaN                    IT     High Net Worth
# 3999         Assistant Manager                    IT     High Net Worth
#
#      deceased_indicator             default owns_car  tenure
# 0                     N  1;DROP TABLE users       No     6.0
# 1                     N  ì¬íê³¼íì ì´íì°êµ¬ì       No     5.0
# 2                     N                   á       No    16.0
# 3                     N                  á       Yes    17.0
# 4                     N  ì¬íê³¼íì ì´íì°êµ¬ì      Yes     8.0
# ...                 ...                 ...      ...     ...
# 3995                  N                 NaN       No     NaN
# 3996                  N                 NaN       No     NaN
# 3997                  N                 NaN      Yes     NaN
# 3998                  N                 NaN      Yes     NaN
# 3999                  N                 NaN       No     NaN
#
# [4000 rows x 13 columns]

# %%
df_trans_sub = df_trans[['customer_id','list_price']]

# %%
new_df= df_trans[["transaction_date"]]

# %%
new_df.columns
# Out:
# Index(['transaction_date'], dtype='object')

# %%
from datetime import date 
  
def calculateAge(born): 
    today = date.today() 
    try:  
        birthday = born.replace(year = today.year) 
  
    # raised when birth date is February 29 
    # and the current year is not a leap year 
    except ValueError:  
        birthday = born.replace(year = today.year, month = born.month + 1, day = 1) 
  
    if birthday > today: 
        return today.year - born.year - 1
    else: 
        return today.year - born.year

# %%
new_df['transaction_date'].apply(lambda x: calculateAge(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-aaa8c4859d2e> in <module>
# ----> 1 new_df['transaction_date'].apply(lambda x: calculateAge(x))
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4211             else:
#    4212                 values = self.astype(object)._values
# -> 4213                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4214
#    4215         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-72-aaa8c4859d2e> in <lambda>(x)
# ----> 1 new_df['transaction_date'].apply(lambda x: calculateAge(x))
#
# <ipython-input-71-07e5af48ad9f> in calculateAge(born)
#       4     today = date.today()
#       5     try:
# ----> 6         birthday = born.replace(year = today.year)
#       7
#       8     # raised when birth date is February 29
#
# TypeError: replace() takes no keyword arguments

# %%
new_df
# Out:
#       transaction_date
# 0              2/25/17
# 1              5/21/17
# 2             10/16/17
# 3              8/31/17
# 4              10/1/17
# ...                ...
# 19995          6/24/17
# 19996          11/9/17
# 19997          4/14/17
# 19998           7/3/17
# 19999          9/22/17
#
# [20000 rows x 1 columns]

# %%
df_merged['DOB'].apply(lambda x: calculateAge(x))

# %%
df_demo.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'default', 'owns_car', 'tenure'],
#       dtype='object')

# %%
df_trans_sub = df_trans[['customer_id','list_price']]

# %%
df_trans_sub.columns
# Out:
# Index(['customer_id', 'list_price'], dtype='object')

# %%
df_trans_sub = df_trans_sub.groupby('customer_id').sum().reset_index()

# %%
df_trans_sub.head(5)
# Out:
#    customer_id  list_price
# 0            1     9084.45
# 1            2     4149.07
# 2            3     9888.23
# 3            4     1047.72
# 4            5     5903.20

# %%
df_merged = pd.merge(df_demo,df_trans_sub, on = 'customer_id', how = 'inner')

# %%
df_merged.head(10)
# Out:
#    customer_id first_name    last_name  gender  \
# 0          720     Darrel        Canet    Male
# 1         1092     Katlin      Creddon  Female
# 2         3410    Merrili      Brittin  Female
# 3         2413      Abbey       Murrow    Male
# 4          658       Donn      Bonnell    Male
# 5         1243    Robbert       Blakey    Male
# 6         1565        Jay  Janiszewski    Male
# 7         1177   Bobbette        Pozzi  Female
# 8         3471      Brita       Afonso  Female
# 9         2813    Lillian     Crookall  Female
#
#    past_3_years_bike_related_purchases       DOB                 job_title  \
# 0                                   67  10/23/31        Recruiting Manager
# 1                                   56   8/22/35        VP Quality Control
# 2                                   93   9/22/40                       NaN
# 3                                   27   8/11/43  Environmental Specialist
# 4                                   38   1/24/44            Tax Accountant
# 5                                   73    8/9/53     Research Assistant II
# 6                                   71   8/17/53      Sales Representative
# 7                                   47   8/31/53              Food Chemist
# 8                                   95    9/5/53          Quality Engineer
# 9                                   51   9/10/53         Chemical Engineer
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Retail  Affluent Customer                  N
# 1                Retail      Mass Customer                  N
# 2              Property      Mass Customer                  N
# 3         Manufacturing     High Net Worth                  N
# 4         Manufacturing  Affluent Customer                  N
# 5                Retail      Mass Customer                  N
# 6                Retail     High Net Worth                  N
# 7                Health  Affluent Customer                  N
# 8                    IT     High Net Worth                  N
# 9         Manufacturing      Mass Customer                  N
#
#               default owns_car  tenure  list_price
# 0  1;DROP TABLE users       No     6.0    13004.35
# 1  ì¬íê³¼íì ì´íì°êµ¬ì       No     5.0     4893.72
# 2                   á       No    16.0     2965.89
# 3                  á       Yes    17.0     8666.87
# 4  ì¬íê³¼íì ì´íì°êµ¬ì      Yes     8.0     5305.31
# 5                  "'       No     8.0    11625.08
# 6                 NaN      Yes    11.0     3083.23
# 7            1.00E+02      Yes     6.0     8367.47
# 8     ÅâÂ´â°ËÃÂ¨ËÃâââ      Yes     8.0     4637.48
# 9          !@#$%^&*()      Yes    11.0     6323.22

# %%
from datetime import date 
  
def calculateAge(born): 
    today = date.today() 
    try:  
        birthday = born.replace(year = today.year) 
  
    # raised when birth date is February 29 
    # and the current year is not a leap year 
    except ValueError:  
        birthday = born.replace(year = today.year, month = born.month + 1, day = 1) 
  
    if birthday > today: 
        return today.year - born.year - 1
    else: 
        return today.year - born.year

# %%
df_merged['age'] = df_merged['DOB'].apply(lambda x: calculateAge(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-d5ea9beef806> in <module>
# ----> 1 df_merged['age'] = df_merged['DOB'].apply(lambda x: calculateAge(x))
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4211             else:
#    4212                 values = self.astype(object)._values
# -> 4213                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4214
#    4215         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-17-d5ea9beef806> in <lambda>(x)
# ----> 1 df_merged['age'] = df_merged['DOB'].apply(lambda x: calculateAge(x))
#
# <ipython-input-16-07e5af48ad9f> in calculateAge(born)
#       4     today = date.today()
#       5     try:
# ----> 6         birthday = born.replace(year = today.year)
#       7
#       8     # raised when birth date is February 29
#
# TypeError: replace() takes no keyword arguments

# %%
df = pd.read_csv("customers.csv",usecols = ['customer_id', 'first_name', 'last_name', 'gender',
       'past_3_years_bike_related_purchases', 'DOB', 'job_title',
       'job_industry_category', 'wealth_segment', 'deceased_indicator',
       'default', 'owns_car', 'tenure'])

# %%
df.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'default', 'owns_car', 'tenure'],
#       dtype='object')

# %%
df
# Out:
#       customer_id      first_name  last_name  gender  \
# 0               1         Laraine  Medendorp       F
# 1               2             Eli    Bockman    Male
# 2               3           Arlin     Dearle    Male
# 3               4          Talbot        NaN    Male
# 4               5  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 3995         3996         Rosalia   Halgarth  Female
# 3996         3997          Blanch     Nisuis  Female
# 3997         3998          Sarene    Woolley       U
# 3998         3999       Patrizius        NaN    Male
# 3999         4000           Kippy    Oldland    Male
#
#       past_3_years_bike_related_purchases       DOB               job_title  \
# 0                                      93  10/12/53     Executive Secretary
# 1                                      81  12/16/80  Administrative Officer
# 2                                      61   1/20/54      Recruiting Manager
# 3                                      33   10/3/61                     NaN
# 4                                      56   5/13/77           Senior Editor
# ...                                   ...       ...                     ...
# 3995                                    8    8/9/75   VP Product Management
# 3996                                   87   7/13/01         Statistician II
# 3997                                   60       NaN       Assistant Manager
# 3998                                   11  10/24/73                     NaN
# 3999                                   76   11/5/91    Software Engineer IV
#
#      job_industry_category     wealth_segment deceased_indicator  \
# 0                   Health      Mass Customer                  N
# 1       Financial Services      Mass Customer                  N
# 2                 Property      Mass Customer                  N
# 3                       IT      Mass Customer                  N
# 4                      NaN  Affluent Customer                  N
# ...                    ...                ...                ...
# 3995                Health      Mass Customer                  N
# 3996         Manufacturing     High Net Worth                  N
# 3997                    IT     High Net Worth                  N
# 3998         Manufacturing  Affluent Customer                  N
# 3999                   NaN  Affluent Customer                  N
#
#                                                 default owns_car  tenure
# 0                                                    "'      Yes    11.0
# 1                          <script>alert('hi')</script>      Yes    16.0
# 2                                                 1-Feb      Yes    15.0
# 3     () { _; } >_[$($())] { touch /tmp/blns.shellsh...       No     7.0
# 4                                                   NIL      Yes     8.0
# ...                                                 ...      ...     ...
# 3995                                          -1.00E+02       No    19.0
# 3996                                           â¦testâ§      Yes     1.0
# 3997                                                NaN       No     NaN
# 3998                             Â¡â¢Â£Â¢âÂ§Â¶â¢ÂªÂºââ       Yes    10.0
# 3999                                                0/0       No    11.0
#
# [4000 rows x 13 columns]

# %%
df_new = pd.read_csv("new.csv")

# %%
df_new.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        ...
#        'Unnamed: 246', 'Unnamed: 247', 'Unnamed: 248', 'Unnamed: 249',
#        'Unnamed: 250', 'Unnamed: 251', 'Unnamed: 252', 'Unnamed: 253',
#        'Unnamed: 254', 'Unnamed: 255'],
#       dtype='object', length=256)

# %%
from datetime import date 
  
def calculateAge(born): 
    today = date.today() 
    try:  
        birthday = born.replace(year = today.year) 
  
    # raised when birth date is February 29 
    # and the current year is not a leap year 
    except ValueError:  
        birthday = born.replace(year = today.year, month = born.month + 1, day = 1) 
  
    if birthday > today: 
        return today.year - born.year - 1
    else: 
        return today.year - born.year

# %%
# Create new dataframe column named 'age' and m
